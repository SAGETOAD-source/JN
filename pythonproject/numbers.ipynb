# %%
5 ** 2
# Out:
# 25

# %%
2+2
# Out:
# 4

# %%
print('C:\this\name')
# Out:
# C:	his
# ame

# %%
print('C:\\this\\name')
# Out:
# C:\this\name

# %%
word = 'Python'
word[0]  # character in position 0

word[5]  # character in position 5
# Out:
# 'n'

# %%
word = 'Python'
word[:5]
word[::-1]
# Out:
# 'nohtyP'
